# %% [markdown]
# # Bölüm A

# %% [markdown]
# Üniversiteden mezun oldunuz ve şimdi harika bir işiniz var! İstanbul'da Etiler'e taşınıyorsunuz ve bir ev satın almak için tasarruf etmeye başlamak istediğinize karar veriyorsunuz. Etiler'de konut fiyatları çok yüksek olduğu için, bir evin peşinatını ödeyebilmeniz için birkaç yıl tasarruf etmeniz gerekeceğini fark ediyorsunuz. Bölüm A'da, aşağıdaki varsayımlara göre peşinatı ödemeye yetecek kadar para biriktirmenizin ne kadar süreceğini belirleyeceğiz:

# %% [markdown]
# * 1.Hayalinizdeki evin maliyetini `toplam_maliyet` olarak tanımlayalım.
# * 2.Maliyetin peşinatı için gereken kısmı `peşinat_oranı` olarak tanımlayalım. Basit olması için, `peşinat_oranı = 0.25 (% 25)` olarak varsayalım.
# * 3. Şu ana kadar biriktirdiğiniz tutarı `mevcut_tasarruflar` olarak adlandıralım. Varsayıaln olarak 0 TL'lik mevcut * tasarrufla başlarsınız.
# * 4. Mevcut birikimlerinize akıllıca yatırım yaptığımızı ve yıllık `r` cinsinden (diğer bir deyişle, her ayın sonunda, birikimlerinize koymak için ek bir `mevcut_tasarruflar * r / 12` fon aldığınızı varsayalım - 12 yıllık bir orandır). Yatırımlarımızın r = 0,04 (% 4) getiri kazandığını varsayalım.
# * 5. Yıllık maaşımızın `yıllık_maaş` olduğunu varsayalım.
# * 6. Her ay maaşımızın belirli bir miktarını peşinat için biriktirmeye ayıracağımızı varsayalım. Bunu `tasarruf_edilen_oran` olarak adlandıralım. Bu değişken ondalık biçimde olmalıdır (yani % 10 için 0,1).
# * 7. Her ayın sonunda, yatırımımızın geri dönüşü artı **aylık maaş**ımızın bir yüzdesi (yıllık maaş / 12) ile tasarruflarınız artırılacaktır.

# %% [markdown]
# Peşinat için yeterince para biriktirmemizin kaç ay süreceğini hesaplamak için bir program yazalım. Ana değişkenlerimizin `float` olmasını isteyeceğizdir, bu nedenle kullanıcı girdilerini `float`'lara çevirmelisiyiz.

# %% [markdown]
# Programımız, kullanıcıdan aşağıdaki değişkenleri girmesini istemelidir:
# * 1. Yıllık başlangıç maaşı (**yıllık_maaş**)
# * 2. Maaşın biriktirilecek kısmı (**tasarruf_edilen_oran**)
# * 3. Hayalimizdeki evin maliyeti (**toplam_maliyet**)

# %% [markdown]
# **İpucu**
#
# Başlamamıza yardımcı olmak için, kodumuzu yazarken muhtemelen izlememiz gereken aşamaların kabaca bir özetini burada bulabiliriz:
#
# * Kullanıcı girdisini alalım. Kullanıcı girdisi alma konusunda yardıma ihtiyacımız varsa `input()` öğesine bakalım. Bu problem seti için, kullanıcıların geçerli bir girdi gireceğini varsayabiliriz (örneğin, bir `int` beklediğinizde bir `dize` girmeyeceklerdir)
# * Bazı durum değişkenlerini (state variables) baştan tanımlayalım. Hangi bilgilere ihtiyacımız olduğuna karar vermeliyiz. Yıllık tutarları ve aylık tutarları temsil eden değerlere dikkat edelim.

# %% [markdown]
# Farklı girdileri deneyelim ve bir peşinat için tasarruf etmenin ne kadar sürdüğünü görelim. Programımız sonuçları aşağıdaki formatta vermelidir:
#
# Örnek 1:
#
# ```python
# Yıllık maaşınızı girin: 120000
# Maaşınızın tasarruf etmek istediğiniz yüzdesini, ondalık olarak girin: .10
# Hayalinizdeki evin maliyetini girin: 1000000
# Ay sayısı: 183
# ```
#
# Örnek 2:
# ```python
# Yıllık maaşınızı girin: 80000
# Maaşınızın tasarruf etmek istediğiniz yüzdesini, ondalık olarak girin: .15
# Hayalinizdeki evin maliyetini girin: 500000
# Ay sayısı: 105
# ```

# %%
peşinat_oranı, mevcut_tasarruflar, r, ay_sayısı = 0.25, 0, 0.04, 0
yıllık_maaş = float(input("Yıllık maaşınızı girin: "))
tasarruf_edilen_oran = float(input("Maaşınızın tasarruf etmek istediğiniz yüzdesini, ondalık olarak girin (örn: .10): "))
toplam_maliyet = float(input("Hayalinizdeki evin maliyetini girin: "))

while mevcut_tasarruflar < toplam_maliyet * peşinat_oranı:
    aylık_getiri = (yıllık_maaş / 12 * tasarruf_edilen_oran) * (1 + (r / 12)) ** ay_sayısı # işlem önceliği üssel ifadede önce çarpımın sağ tarafı yapılıyor, sonrasında (yıllık maaş / 12 * tasarruf_edilen_oran) ile çarpılıp aylık getiri hesaplanıyor. aylık bileşik faiz formülü kullanıldı
    mevcut_tasarruflar += aylık_getiri
    ay_sayısı += 1
    # print(mevcut_tasarruflar, ay_sayısı)
	# üstteki printi yorumdan cıkarırsanız hesaplama adımlarını görebilirsiniz
print(f"Ay sayısı: {ay_sayısı}")
# Out:
# Yıllık maaşınızı girin: 120000
# Maaşınızın tasarruf etmek istediğiniz yüzdesini, ondalık olarak girin (örn: .10): 0.10
# Hayalinizdeki evin maliyetini girin: 1000000
# Ay sayısı: 183

# %% [markdown]
# # Bölüm B

# %% [markdown]
# Bölüm A'da gerçekçi olmayan bir biçimde maaşımızın değişmediğini varsaydık. Fakat gerçekten iyi çalışıyruz ve şirketimiz için oldukça değerliyiz. Bölüm A'daki çözümümüz üzerine, her 6 ayda bir maaşımıza zam yapıldığını varsayacağız.

# %% [markdown]
# Bölüm A'da yazdığımız programı geliştirelim:
#
# * 1. Kulanıcıdan yarıyıl maaş zammı oranını `yaryıyıl_maaş_zammı_oranı` (ondalık yüzde olarak) girdi olarak alalım.
# * 2. 6-ıncı aydan sonra maaşımız bu yüzde ile artsın. Aynı artış, 12-inci aydan sonra da, 18-inci aydan sonra da vs. gerçekleşsin.

# %% [markdown]
# Peşinat için yeterince para biriktirmenin kaç ay süreceğini hesaplamak için bir program yazalım. Daha önce, yatırımlarımızın r = 0,04 (veya % 4) getiri kazandığını ve gerekli peşinat yüzdesinin 0,25 (veya % 25) olduğunu varsayalım. Kullanıcı aşağıdaki değişkenleri girsin:
#
# * 1. Yıllık başlangıç maaşı (**yıllık_maaş**)
# * 2. Maaşın biriktirilecek kısmı (**tasarruf_edilen_oran**)
# * 3. Hayalimizdeki evin maliyeti (**toplam_maliyet**)
# * 4. Yarıyıl maaş oranı (**yarıyıl_maaş_zammı_oranı**)

# %% [markdown]
# **İpucu**
#
# Başlamamıza yardımcı olmak için, kodumuzu yazarken muhtemelen izlememiz gereken aşamaların kabaca bir özetini burada bulabiliriz:
#
# * Kullanıcıdan girdileri alalım.
# * Bazı durum değişkenlerini (state variables) baştan tanımlayalım. Hangi bilgilere ihtiyacımız olduğuna karar vermeliyiz. Yıllık tutarları ve aylık tutarları temsil eden değerlere dikkat edelim.
# * Maaşınızı ne zaman artıracağınıza dikkat edelim - bu yalnızca 6., 12., 18. aydan sonra olmalıdır.

# %%
peşinat_oranı, r = 0.25, 0.04
toplam_maliyet= float(input("Alacağınız evin toplam maliyeti nedir?: " ))
yıllık_maas =float(input("Yıllık maaşınızı giriniz: "))
tasarruf_edilen_oran = float(input("Maaşınızın ondalık cinsinden (0.1 vb) tasarruf yüzdesini girin : "))
yarıyıl_maaş_zammı_oranı = float(input("Maaşınızın yarıyıl zam oranını giriniz:"))  
aylik_gelir = (yıllık_maas/12)
peşinat =peşinat_oranı*toplam_maliyet
ay_sayisi=0
mevcut_tasarruflar =0 

while mevcut_tasarruflar<= peşinat:
    mevcut_tasarruflar += tasarruf_edilen_oran /12 *yıllık_maas + mevcut_tasarruflar*r/12
    ay_sayisi +=1 
    
    if ay_sayisi%6==0:
        yıllık_maas += yıllık_maas*yarıyıl_maaş_zammı_oranı
    print(mevcut_tasarruflar, ay_sayisi) 
    
print("{} ay biriktirmelisin mevcut tutar {}. ".format(ay_sayisi, mevcut_tasarruflar))
# Out:
# Alacağınız evin toplam maliyeti nedir?: 800000
# Yıllık maaşınızı giriniz: 8000
# Maaşınızın ondalık cinsinden (0.1 vb) tasarruf yüzdesini girin : 0.10
# Maaşınızın yarıyıl zam oranını giriniz:0.10
# 66.66666666666667 1
# 133.55555555555557 2
# 200.66740740740744 3
# 268.0029654320988 4
# 335.56297531687244 5
# 403.34818523459535 6
# 478.0260125187107 7
# 552.9527658937731 8
# 628.129275113419 9
# 703.5563726971304 10
# 779.2348939394542 11
# 855.1656769192524 12
# 938.6828958423166 13
# 1022.4785054951243 14
# 1106.5534338467746 15
# 1190.9086119595972 16
# 1275.5449739994626 17
# 1360.4634572461275 18
# 1453.7316687702812 19
# 1547.3107743328487 20
# 1641.2018102472916 21
# 1735.4058162814492 22
# 1829.9238356690541 23
# 1924.7569151212842 24
# 2028.7794381716885 25
# 2133.148702965594 26
# 2237.8658653088128 27
# 2342.9320848598422 28
# 2448.3485251427082 29
# 2554.1163535598507 30
# 2669.997408071717 31
# 2786.2647327652894 32
# 2902.9196152078403 33
# 3019.963347258533 34
# 3137.397225082728 35
# 3255.222549166337 36
# 3384.1773576635583 37
# 3513.562015522437 38
# 3643.3779555741785 39
# 3773.6266154260925 40
# 3904.309437477513 41
# 4035.427868935771 42
# 4178.79376849889 43
# 4322.637554393887 44
# 4466.9608195752 45
# 4611.765162307117 46
# 4757.052186181474 47
# 4902.823500135412 48
# 5062.07216580253 49
# 5221.851660355205 50
# 5382.163753223056 51
# 5543.010219733799 52
# 5704.392841132912 53
# 5866.313404603355 54
# 6043.064295352033 55
# 6220.404355736539 56
# 6398.335549655661 57
# 6576.859847554513 58
# 6755.979226446361 59
# 6935.6956699345155 60
# 7131.73081950763 61
# 7328.4194195793225 62
# 7525.76364831792 63
# 7723.765691152314 64
# 7922.4277407961545 65
# 8121.751997272142 66
# 8339.032284337049 67
# 8557.036839025506 68
# 8775.768075562924 69
# 8995.228416222135 70
# 9215.420291350209 71
# 9436.346139395377 72
# 9677.029184974761 73
# 9918.514507372744 74
# 10160.804780845387 75
# 10403.902688562937 76
# 10647.810922639546 77
# 10892.532184163078 78
# 11158.992039069828 79
# 11426.340093492934 80
# 11694.57930809745 81
# 11963.712653417315 82
# 12233.743109888246 83
# 12504.673667880747 84
# 12799.52246916251 85
# 13095.354099781878 86
# 13392.171835836645 87
# 13689.978964344928 88
# 13988.778783281572 89
# 14288.574601614671 90
# 14614.68639491443 91
# 14941.885227525188 92
# 15270.174722911315 93
# 15599.558516615396 94
# 15930.040256298491 95
# 16261.62360178053 96
# 16622.160546210278 97
# 16983.899280454792 98
# 17346.843810480124 99
# 17710.99815560554 100
# 18076.36634854804 101
# 18442.952435467014 102
# 18841.393629251434 103
# 19241.16296034847 104
# 19642.26485588249 105
# 20044.703757734962 106
# 20448.484122593607 107
# 20853.61042200178 108
# 21293.783610974602 109
# 21735.424043910665 110
# 22178.53661162318 111
# 22623.126221228074 112
# 23069.197796198318 113
# 23516.756276418462 114
# 24002.87273366262 115
# 24490.609579097592 116
# 24979.972214017347 117
# 25470.96605772017 118
# 25963.596547568664 119
# 26457.86913904999 120
# 26994.562032801863 121
# 27533.043902866244 122
# 28073.320712497505 123
# 28615.398444827537 124
# 29159.283102932 125
# 29704.980709896812 126
# 30297.34730854701 127
# 30891.688462526043 128
# 31488.01075368501 129
# 32086.320785814503 130
# 32686.625184717763 131
# 33288.93059828403 132
# 33942.578696190576 133
# 34598.40562109014 134
# 35256.41863573937 135
# 35916.6250271041 136
# 36579.03210644004 137
# 37243.647209373776 138
# 37964.74619557518 139
# 38688.24884506392 140
# 39414.16317005096 141
# 40142.497209454625 142
# 40873.25902898963 143
# 41606.45672125642 144
# 42401.79375538111 145
# 43199.781912952894 146
# 44000.43003104991 147
# 44803.74697620725 148
# 45609.74164451512 149
# 46418.42296171734 150
# 47295.464767815625 151
# 48175.4300466009 152
# 49058.328542982126 153
# 49944.17003435129 154
# 50832.96433069169 155
# 51724.721274686555 156
# 52691.682114783995 157
# 53661.866157681754 158
# 54635.284147389175 159
# 55611.946863728954 160
# 56591.86512245653 161
# 57575.04977537987 162
# 58640.966220731134 163
# 59710.435720900234 164
# 60783.47011940323 165
# 61860.081299234575 166
# 62940.28118299868 167
# 64024.081733042 168
# 65198.89491286214 169
# 66377.624136615 170
# 67560.28245778038 171
# 68746.88297334965 172
# 69937.43882397082 173
# 71131.96319409405 174
# 72426.60926952201 175
# 73725.57083186808 176
# 75028.86226608863 177
# 76336.49800508992 178
# 77648.49252988788 179
# 78964.8603697685 180
# 80391.37005559349 181
# 81822.63477370456 182
# 83258.67037420934 183
# 84699.49276004914 184
# 86145.11788717506 185
# 87595.56176472474 186
# 89167.16980365882 187
# 90744.01653605602 188
# 92326.11942422787 189
# 93913.49598869364 190
# 95506.16380837429 191
# 97104.1405207872 192
# 98835.40610554666 193
# 100572.44257558865 194
# 102315.26916719745 195
# 104063.90518077828 196
# 105818.36998107105 197
# 107578.6829973648 198
# 109485.62223534854 199
# 111398.91793745889 200
# 113318.5912919096 201
# 115244.66355754182 202
# 117177.15606405948 203
# 119116.09021226554 204
# 121216.32183709819 205
# 123323.55423401363 206
# 125437.81073891878 207
# 127559.11476550695 208
# 129687.48980551708 209
# 131822.9594289939 210
# 134135.86508362816 211
# 136456.48042377786 212
# 138784.83114839473 213
# 141120.94304209366 214
# 143464.84197543826 215
# 145816.55390522734 216
# 148363.45445376946 217
# 150918.84467080675 218
# 153482.75285523414 219
# 156055.2074002763 220
# 158636.23679380192 221
# 161225.8696186393 222
# 164030.2190897786 223
# 166843.91639248838 224
# 169666.99268620717 225
# 172499.4792342384 226
# 175341.40740409636 227
# 178192.80866785385 228
# 181280.40759306494 229
# 184378.2985146934 230
# 187486.51573939394 231
# 190605.09368817683 232
# 193734.06689678898 233
# 196873.47001609651 234
# 200272.70010210024 235
# 235 ay biriktirmelisin mevcut tutar 200272.70010210024.
